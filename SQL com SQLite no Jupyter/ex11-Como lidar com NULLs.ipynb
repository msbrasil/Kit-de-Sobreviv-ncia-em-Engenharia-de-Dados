# %% [markdown]
# É possível lidar com valores nulos usando usando `NOT NULL`. Porém, isso não é muito útil, pois muitas vezes não sabemos se um valor é nulo ou não. Por exemplo, se um usuário não preencher um campo de um formulário, o valor desse campo será nulo.
#
# Pode-se dar um valor padrão para nulos com a função `COALESCE`.

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# Primeiro, vou trazer um exeplo de base com valores nulos para trabalhar:

# %%
con = sqlite3.connect('../primeiro_banco')
cur = con.cursor()
print('conexão aberta')
# Out:
# conexão aberta

# %%
query = 'SELECT * FROM Customers LIMIT 3'

df = pd.read_sql_query(query, con)
df
# Out:
#    CustomerKey FirstName LastName  BirthDate MaritalStatus Gender  \
# 0        11000       JON     YANG   4/8/1966             M      M
# 1        11001    EUGENE    HUANG  5/14/1965             S      M
# 2        11002     RUBEN   TORRES  8/12/1965             M      M
#
#                    EmailAddress  AnnualIncome  TotalChildren EducationLevel  \
# 0     jon24@adventure-works.com       90000.0              2      Bachelors
# 1  eugene10@adventure-works.com       60000.0              3      Bachelors
# 2   ruben35@adventure-works.com       60000.0              3      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y

# %% [markdown]
# Criar uma tabela com valores nulos

# %%
con.executescript('''
DROP TABLE IF EXISTS Customers_bk;
CREATE TABLE Customers_bk AS SELECT * FROM Customers;
'''
)

con.commit()

# %%
query = 'SELECT * FROM Customers_bk LIMIT 3'

df = pd.read_sql_query(query, con)
df
# Out:
#    CustomerKey FirstName LastName  BirthDate MaritalStatus Gender  \
# 0        11000       JON     YANG   4/8/1966             M      M
# 1        11001    EUGENE    HUANG  5/14/1965             S      M
# 2        11002     RUBEN   TORRES  8/12/1965             M      M
#
#                    EmailAddress  AnnualIncome  TotalChildren EducationLevel  \
# 0     jon24@adventure-works.com       90000.0              2      Bachelors
# 1  eugene10@adventure-works.com           NaN              3      Bachelors
# 2   ruben35@adventure-works.com           NaN              3      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y

# %%
con.executescript('''
    UPDATE Customers_bk
    SET AnnualIncome = NULL
    WHERE AnnualIncome < 70000;
    '''
)

con.commit()

# %% [markdown]
# Encontrar valores nulos

# %%
query = '''
SELECT * 
FROM Customers_bk
WHERE AnnualIncome IS NULL
'''

df = pd.read_sql_query(query, con)
df
# Out:
#        CustomerKey FirstName LastName   BirthDate MaritalStatus Gender  \
# 0            11001    EUGENE    HUANG   5/14/1965             S      M
# 1            11002     RUBEN   TORRES   8/12/1965             M      M
# 2            11007     MARCO    MEHTA    5/9/1964             M      M
# 3            11008     ROBIN  VERHOFF    7/7/1964             S      F
# 4            11011    CURTIS       LU   11/4/1963             M      M
# ...            ...       ...      ...         ...           ...    ...
# 11532        29479     TOMMY     TANG    7/4/1958             M      M
# 11533        29480      NINA     RAJI  11/10/1960             S      F
# 11534        29481      IVAN     SURI    1/5/1960             S      M
# 11535        29482   CLAYTON    ZHANG    3/5/1959             M      M
# 11536        29483     JÉSUS  NAVARRO   12/8/1959             M      M
#
#                        EmailAddress AnnualIncome  TotalChildren  \
# 0      eugene10@adventure-works.com         None              3
# 1       ruben35@adventure-works.com         None              3
# 2       marco14@adventure-works.com         None              3
# 3          rob4@adventure-works.com         None              4
# 4       curtis9@adventure-works.com         None              4
# ...                             ...          ...            ...
# 11532    tommy2@adventure-works.com         None              1
# 11533    nina21@adventure-works.com         None              3
# 11534     ivan0@adventure-works.com         None              3
# 11535  clayton0@adventure-works.com         None              3
# 11536    jésus9@adventure-works.com         None              0
#
#         EducationLevel    Occupation HomeOwner
# 0            Bachelors  Professional         N
# 1            Bachelors  Professional         Y
# 2            Bachelors  Professional         Y
# 3            Bachelors  Professional         Y
# 4            Bachelors  Professional         Y
# ...                ...           ...       ...
# 11532  Graduate Degree      Clerical         Y
# 11533  Graduate Degree      Clerical         Y
# 11534  Graduate Degree      Clerical         N
# 11535        Bachelors      Clerical         Y
# 11536        Bachelors      Clerical         Y
#
# [11537 rows x 12 columns]

# %%
query = '''
SELECT COUNT(*) AS Nulos
FROM Customers_bk
WHERE AnnualIncome IS NULL
'''

df = pd.read_sql_query(query, con)
df
# Out:
#    Nulos
# 0  11537

# %% [markdown]
# Formas de lidar com nulos

# %% [markdown]
# Não usar as linhas com valores nulos

# %%
query = '''
SELECT *
FROM Customers_bk
WHERE AnnualIncome IS NOT NULL
'''

df = pd.read_sql_query(query, con)
df
# Out:
#       CustomerKey  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0           11000        JON     YANG    4/8/1966             M      M
# 1           11003    CHRISTY      ZHU   2/15/1968             S      F
# 2           11004  ELIZABETH  JOHNSON    8/8/1968             S      F
# 3           11005      JULIO     RUIZ    8/5/1965             S      M
# 4           11009    SHANNON  CARLSON    4/1/1964             S      M
# ...           ...        ...      ...         ...           ...    ...
# 6606        29317      JAMES     HILL    7/3/1958             S      M
# 6607        29318      EDGAR    PEREZ  11/18/1958             M      M
# 6608        29319      ALVIN      PAL   7/14/1957             S      M
# 6609        29320     WESLEY    HUANG   2/14/1960             M      M
# 6610        29321      ROGER    ZHENG    9/2/1960             S      M
#
#                         EmailAddress  AnnualIncome  TotalChildren  \
# 0          jon24@adventure-works.com       90000.0              2
# 1      christy12@adventure-works.com       70000.0              0
# 2     elizabeth5@adventure-works.com       80000.0              5
# 3         julio1@adventure-works.com       70000.0              0
# 4      shannon38@adventure-works.com       70000.0              0
# ...                              ...           ...            ...
# 6606     james64@adventure-works.com       90000.0              2
# 6607     edgar22@adventure-works.com      100000.0              4
# 6608     alvin34@adventure-works.com       70000.0              1
# 6609     wesley6@adventure-works.com       70000.0              5
# 6610     roger23@adventure-works.com       70000.0              5
#
#        EducationLevel      Occupation HomeOwner
# 0           Bachelors    Professional         Y
# 1           Bachelors    Professional         N
# 2           Bachelors    Professional         Y
# 3           Bachelors    Professional         Y
# 4           Bachelors    Professional         N
# ...               ...             ...       ...
# 6606        Bachelors    Professional         N
# 6607        Bachelors      Management         Y
# 6608  Partial College  Skilled Manual         N
# 6609  Partial College  Skilled Manual         N
# 6610  Partial College  Skilled Manual         Y
#
# [6611 rows x 12 columns]

# %% [markdown]
# Calcular os valores de nulos e nao nulos

# %%
query = '''
SELECT SUM(CASE WHEN AnnualIncome IS NULL THEN 1 ELSE 0 END) AS Nulos,
    SUM(CASE WHEN AnnualIncome IS NOT NULL THEN 1 ELSE 0 END) AS NaoNulos,
    COUNT(*) AS Total
FROM Customers_bk
'''

df = pd.read_sql_query(query, con)
df
# Out:
#    Nulos  NaoNulos  Total
# 0  11537      6611  18148

# %% [markdown]
# Substituir valores nulos com valores sensíveis

# %%
query = 'SELECT ROUND(AVG(AnnualIncome), 0) FROM Customers_bk'

df = pd.read_sql_query(query, con)
df
# Out:
#    ROUND(AVG(AnnualIncome), 0)
# 0                      90924.0

# %%
query = '''
SELECT *, COALESCE(AnnualIncome, 90924) AS Income
FROM Customers_bk
'''

df = pd.read_sql_query(query, con)
df
# Out:
#        CustomerKey  FirstName LastName   BirthDate MaritalStatus Gender  \
# 0            11000        JON     YANG    4/8/1966             M      M
# 1            11001     EUGENE    HUANG   5/14/1965             S      M
# 2            11002      RUBEN   TORRES   8/12/1965             M      M
# 3            11003    CHRISTY      ZHU   2/15/1968             S      F
# 4            11004  ELIZABETH  JOHNSON    8/8/1968             S      F
# ...            ...        ...      ...         ...           ...    ...
# 18143        29479      TOMMY     TANG    7/4/1958             M      M
# 18144        29480       NINA     RAJI  11/10/1960             S      F
# 18145        29481       IVAN     SURI    1/5/1960             S      M
# 18146        29482    CLAYTON    ZHANG    3/5/1959             M      M
# 18147        29483      JÉSUS  NAVARRO   12/8/1959             M      M
#
#                          EmailAddress  AnnualIncome  TotalChildren  \
# 0           jon24@adventure-works.com       90000.0              2
# 1        eugene10@adventure-works.com           NaN              3
# 2         ruben35@adventure-works.com           NaN              3
# 3       christy12@adventure-works.com       70000.0              0
# 4      elizabeth5@adventure-works.com       80000.0              5
# ...                               ...           ...            ...
# 18143      tommy2@adventure-works.com           NaN              1
# 18144      nina21@adventure-works.com           NaN              3
# 18145       ivan0@adventure-works.com           NaN              3
# 18146    clayton0@adventure-works.com           NaN              3
# 18147      jésus9@adventure-works.com           NaN              0
#
#         EducationLevel    Occupation HomeOwner   Income
# 0            Bachelors  Professional         Y  90000.0
# 1            Bachelors  Professional         N  90924.0
# 2            Bachelors  Professional         Y  90924.0
# 3            Bachelors  Professional         N  70000.0
# 4            Bachelors  Professional         Y  80000.0
# ...                ...           ...       ...      ...
# 18143  Graduate Degree      Clerical         Y  90924.0
# 18144  Graduate Degree      Clerical         Y  90924.0
# 18145  Graduate Degree      Clerical         N  90924.0
# 18146        Bachelors      Clerical         Y  90924.0
# 18147        Bachelors      Clerical         Y  90924.0
#
# [18148 rows x 13 columns]
